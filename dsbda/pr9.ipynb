# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\supriya\appdata\roaming\python\python312\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from requests) (2025.1.31)

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: beautifulsoup4 in c:\users\supriya\appdata\roaming\python\python312\site-packages (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from beautifulsoup4) (4.12.2)

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\supriya\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\supriya\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import libraries

import requests

from bs4 import BeautifulSoup

import pandas as pd

# %%
# Website URL

url = "https://books.toscrape.com/"

# %%
# Send request

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
# Parse HTML

soup = BeautifulSoup(response.text, "html.parser")

# %%
# Find all book titles

books = soup.find_all("h3")

for book in books[:10]:
    
    print(book.text)
# Out:
# A Light in the ...
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History ...
# The Requiem Red
# The Dirty Little Secrets ...
# The Coming Woman: A ...
# The Boys in the ...
# The Black Maria

# %%
# Create empty lists

book_name = []

price = []

# %%
# Find product containers

products = soup.find_all("article", class_="product_pod")

for item in products:
    
    # Book name
    name = item.h3.a["title"]
    
    # Book price
    cost = item.find("p", class_="price_color").text
    
    # Append values
    book_name.append(name)
    
    price.append(cost)

# %%
# Create dataframe

data = pd.DataFrame({
    
    "Book Name": book_name,
    
    "Price": price
})

print(data.head())
# Out:
#                                Book Name    Price
# 0                   A Light in the Attic  Â£51.77
# 1                     Tipping the Velvet  Â£53.74
# 2                             Soumission  Â£50.10
# 3                          Sharp Objects  Â£47.82
# 4  Sapiens: A Brief History of Humankind  Â£54.23

# %%
# Save output CSV file

data.to_csv("book_reviews_output.csv", index=False)

print("Output file generated successfully")
# Out:
# Output file generated successfully
